# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

import pylab as p
import numpy as np
import pandas as pd

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.6287311  2.6607409  2.87992962 2.03440245 2.23502438 2.06040598
#  2.5955542  2.85018621 2.40482633 2.15638044]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniformed_distribution_numbers(bottom, ceiling, count):
    my_uniform = uniform(bottom,ceiling)
    sample = my_uniform.rvs(count)
    return sample
    
print(uniformed_distribution_numbers(10, 15, 100))
print(uniformed_distribution_numbers(10, 60, 1000))

sample = uniformed_distribution_numbers(10, 15, 100)
sample_2 = uniformed_distribution_numbers(10, 60, 1000)
# Out:
# [15.89696938 13.48442715 10.85007147 15.18443109 17.4855291  21.76568049
#  20.15849566 11.87888577 14.6430512  22.03832204 24.27774006 24.61352166
#  14.46227346 22.82008329 20.27092714 16.7274367  15.71766127 10.01911122
#  19.75757448 22.64733956 18.03094153 14.83978017 24.45320047 12.80386791
#  19.05146068 13.0320803  13.40607256 11.25022371 24.37889009 22.23894748
#  11.96356236 20.14445647 16.00085892 19.63557395 14.8281592  13.14322947
#  17.43138008 15.22809784 23.81727461 21.60957503 16.14025339 23.82768924
#  15.29095646 22.36669694 11.87168776 22.14190425 11.1676332  12.7335994
#  14.1945482  12.09319738 19.11689967 13.40874836 22.62591171 22.73606931
#  21.30974007 17.77776794 24.60378967 22.95298496 10.46667199 12.44221594
#  22.93815046 18.35430227 19.92067422 10.98466774 15.69492662 19.47397524
#  20.78975258 19.103975   23.41398936 16.80343952 10.4428416  23.16940726
#  20.86235546 19.11289174 13.68940491 24.57811034 11.96080446 24.89730565
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axs = plt.subplots(ncols=2)
ax1 = plt.subplot(131)
ax1.set_ylim([0, 120])
ax2 = plt.subplot(132)
ax2.set_ylim([0, 120])
ax1.hist(uniformed_distribution_numbers(10,15,100), bins=10)
ax2.hist(uniformed_distribution_numbers(10,60,1000), bins=10)
# Out:
# (array([103.,  97.,  93., 102., 114.,  96., 100., 117.,  89.,  89.]),
#  array([10.02374054, 16.01672917, 22.0097178 , 28.00270643, 33.99569506,
#         39.98868369, 45.98167232, 51.97466095, 57.96764958, 63.96063821,
#         69.95362685]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# How are the two distributions different?

# %%
# they are diff just look at them

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
my_normal = norm(loc=170, scale=10)


def normal_distribution_numbers(average, dev, sample):
    my_normal = norm(loc=average, scale=dev)
    sample = my_normal.rvs(size=sample)
    return sample

sample_1 = normal_distribution_numbers(10, 1, 1000)
sample_2 = normal_distribution_numbers(10, 50, 1000)

# %%
fig, axs = plt.subplots(ncols=2)
ax1 = plt.subplot(131)
ax1.set_ylim([0, 70])
ax2 = plt.subplot(132)
ax2.set_ylim([0, 70])
ax1.hist(normal_distribution_numbers(10, 1, 1000), bins=60)
ax2.hist(normal_distribution_numbers(10, 50, 1000), bins=60)
# Out:
# (array([ 1.,  1.,  2.,  3.,  2.,  0.,  2.,  0.,  4.,  2.,  5.,  3.,  6.,
#         10., 16., 19., 21., 15., 22., 23., 19., 27., 32., 26., 23., 32.,
#         37., 38., 38., 37., 32., 46., 48., 44., 37., 30., 24., 29., 24.,
#         35., 26., 14., 24., 20., 24., 14.,  9., 10., 13.,  5.,  3.,  4.,
#          7.,  2.,  4.,  1.,  1.,  1.,  1.,  2.]),
#  array([-140.3571175 , -135.43350061, -130.50988372, -125.58626682,
#         -120.66264993, -115.73903304, -110.81541615, -105.89179926,
#         -100.96818237,  -96.04456548,  -91.12094858,  -86.19733169,
#          -81.2737148 ,  -76.35009791,  -71.42648102,  -66.50286413,
#          -61.57924724,  -56.65563034,  -51.73201345,  -46.80839656,
#          -41.88477967,  -36.96116278,  -32.03754589,  -27.11392899,
#          -22.1903121 ,  -17.26669521,  -12.34307832,   -7.41946143,
#           -2.49584454,    2.42777235,    7.35138925,   12.27500614,
#           17.19862303,   22.12223992,   27.04585681,   31.9694737 ,
# ...

# %% [markdown]
# How are the two distributions different?

# %%
## they are different becouse one is from 0 to 15 and the other is -150 to 150.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
GSAF = r"C:\Users\lenovo\Desktop\continuos_prob\lab-continuous-probability-distributions\your-code\vehicles.csv"

df = pd.read_csv(GSAF, encoding = "ISO-8859-1")
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
df_Years = df.groupby('Year',as_index=False).sum()
df_Years
# Out:
#     Year  Engine Displacement  Cylinders  Fuel Barrels/Year  City MPG  \
# 0   1984               2533.4     3936.0       13664.448970      9988
# 1   1985               5012.5     8519.0       28600.372182     28256
# 2   1986               3783.5     6452.0       21623.415503     20999
# 3   1987               3760.3     6451.0       22011.963864     20863
# 4   1988               3582.7     6120.0       20490.272457     19383
# 5   1989               3607.2     6172.0       20844.777534     19341
# 6   1990               3437.5     5872.0       19805.704202     18194
# 7   1991               3670.9     6287.0       21010.595617     18892
# 8   1992               3630.2     6231.0       20634.951640     18598
# 9   1993               3492.8     6026.0       19715.684999     18341
# 10  1994               3232.0     5524.0       17744.453937     16358
# 11  1995               3212.8     5446.0       17285.998589     15404
# ...

# %%
df_Years.plot(x = "Year", y="Fuel Barrels/Year") # ahha was not this
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.hist(column = "Fuel Barrels/Year")
# Out:
# array([[<AxesSubplot:title={'center':'Fuel Barrels/Year'}>]], dtype=object)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
df.hist(column = "CO2 Emission Grams/Mile")
# Out:
# array([[<AxesSubplot:title={'center':'CO2 Emission Grams/Mile'}>]],
#       dtype=object)

# %% [markdown]
# 3. Combined MPG

# %%
df.hist(column = "Combined MPG")
# Out:
# array([[<AxesSubplot:title={'center':'Combined MPG'}>]], dtype=object)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#the fuel barrels per year is normally distributed becouse it has a normal distribution figure. The probability density function (PDF or PDF in English) is positive throughout its domain and its integral over the entire space is of unit value

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponential_sample(count):
    return np.random.exponential(scale=10, size=count)

# %%
fig, axs = plt.subplots(ncols=2)
ax1 = plt.subplot(131)
ax2 = plt.subplot(132)
ax1.hist(exponential_sample(1000), bins = 100)
ax2.hist(exponential_sample(100000), bins = 100)
# Out:
# (array([1.1658e+04, 1.0159e+04, 9.1110e+03, 8.0670e+03, 6.9800e+03,
#         6.2210e+03, 5.5460e+03, 4.9550e+03, 4.2440e+03, 3.7990e+03,
#         3.3750e+03, 2.9050e+03, 2.6920e+03, 2.3260e+03, 2.1350e+03,
#         1.7940e+03, 1.6030e+03, 1.4380e+03, 1.2700e+03, 1.1750e+03,
#         9.7300e+02, 8.2700e+02, 7.8500e+02, 6.6900e+02, 6.4100e+02,
#         4.7700e+02, 5.0000e+02, 4.5000e+02, 3.8500e+02, 3.2900e+02,
#         2.8900e+02, 2.8000e+02, 2.3700e+02, 1.9500e+02, 1.7500e+02,
#         1.4700e+02, 1.2200e+02, 1.2100e+02, 1.0500e+02, 9.3000e+01,
#         9.2000e+01, 7.3000e+01, 4.6000e+01, 6.6000e+01, 5.9000e+01,
#         6.0000e+01, 3.7000e+01, 3.7000e+01, 3.2000e+01, 1.8000e+01,
#         2.8000e+01, 2.6000e+01, 2.5000e+01, 1.9000e+01, 1.5000e+01,
#         1.3000e+01, 1.2000e+01, 6.0000e+00, 1.1000e+01, 7.0000e+00,
#         2.0000e+00, 1.0000e+01, 9.0000e+00, 5.0000e+00, 4.0000e+00,
#         1.0000e+00, 2.0000e+00, 2.0000e+00, 4.0000e+00, 2.0000e+00,
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# one is much more continuous and the other one is not, it have irregular data.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon
my_e = expon(scale=10)
my_e.cdf(15)
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1-my_e.cdf(15)
# Out:
# 0.2231301601484298
